# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/16726/Computer-vision-learning/final_proj/
# Out:
# /content/drive/MyDrive/16726/Computer-vision-learning/final_proj

# %%
# !git clone https://github.com/lucidrains/gigagan-pytorch
# Out:
# Cloning into 'gigagan-pytorch'...
# remote: Enumerating objects: 107, done.
# remote: Counting objects: 100% (107/107), done.
# remote: Compressing objects: 100% (83/83), done.
# remote: Total 107 (delta 48), reused 73 (delta 21), pack-reused 0
# Receiving objects: 100% (107/107), 929.38 KiB | 12.07 MiB/s, done.
# Resolving deltas: 100% (48/48), done.

# %%
# %cd gigagan-pytorch
# Out:
# /content/drive/MyDrive/16726/Computer-vision-learning/final_proj/gigagan-pytorch

# %%
# !python setup.py install
# Out:
# running install
# /usr/local/lib/python3.9/dist-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/setuptools/command/easy_install.py:144: EasyInstallDeprecationWarning: easy_install command is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# running bdist_egg
# running egg_info
# creating gigagan_pytorch.egg-info
# writing gigagan_pytorch.egg-info/PKG-INFO
# writing dependency_links to gigagan_pytorch.egg-info/dependency_links.txt
# writing requirements to gigagan_pytorch.egg-info/requires.txt
# writing top-level names to gigagan_pytorch.egg-info/top_level.txt
# writing manifest file 'gigagan_pytorch.egg-info/SOURCES.txt'
# reading manifest file 'gigagan_pytorch.egg-info/SOURCES.txt'
# adding license file 'LICENSE'
# writing manifest file 'gigagan_pytorch.egg-info/SOURCES.txt'
# ...
